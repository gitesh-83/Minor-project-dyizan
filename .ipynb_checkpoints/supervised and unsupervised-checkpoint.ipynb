# %% [raw]
# Based on the research into supervised and unsupervised learning concepts:
#
# **SUPERVISED LEARNING:**
# - Definition: A machine learning approach where algorithms learn from labeled training data
# - Key Characteristics:
#   * Uses input-output pairs (X, y) for training
#   * Goal is to learn a mapping function from inputs to known outputs
#   * Performance can be measured against ground truth labels
#   * Examples: Email spam detection, image classification, medical diagnosis
#
# - Types:
#   1. Classification: Predicting discrete categories (e.g., spam/not spam)
#   2. Regression: Predicting continuous values (e.g., house prices)
#
# - Popular Algorithms: Logistic Regression, Decision Trees, Random Forest, SVM, Neural Networks
#
# - Advantages:
#   * Clear performance metrics (accuracy, precision, recall)
#   * Well-defined objectives
#   * Strong predictive capabilities on similar data
#
# - Challenges:
#   * Requires labeled data (expensive to obtain)
#   * May not generalize to different data distributions
#   * Can overfit to training patterns
#
# **UNSUPERVISED LEARNING:**
# - Definition: Learning patterns from data without labeled examples or known target outputs
# - Key Characteristics:
#   * Uses only input data (X) without target labels
#   * Goal is to discover hidden patterns, structures, or relationships
#   * More exploratory in nature
#   * Examples: Customer segmentation, anomaly detection, data compression
#
# - Types:
#   1. Clustering: Grouping similar data points (K-means, hierarchical clustering)
#   2. Association Rules: Finding relationships between variables
#   3. Dimensionality Reduction: Reducing feature space while preserving information (PCA)
#
# - Popular Algorithms: K-Means, DBSCAN, PCA, Apriori, Gaussian Mixture Models
#
# - Advantages:
#   * No need for expensive labeled data
#   * Can discover unknown patterns
#   * Useful for exploratory data analysis
#   * Helps understand data structure
#
# - Challenges:
#   * Difficult to evaluate results objectively
#   * May find spurious patterns
#   * Interpretation can be subjective
#
# **KEY DIFFERENCES:**
# 1. Data Requirements: Supervised needs labels, unsupervised doesn't
# 2. Objective: Supervised predicts outcomes, unsupervised discovers patterns
# 3. Evaluation: Supervised has clear metrics, unsupervised evaluation is more complex
# 4. Applications: Supervised for prediction tasks, unsupervised for exploration
#
# **PRACTICAL EXAMPLE FROM OUR ANALYSIS:**
# - Supervised: Iris flower classification achieved 100% accuracy on test data
# - Unsupervised: K-means clustering on iris data achieved 73% agreement with true species labels
